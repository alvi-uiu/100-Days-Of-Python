# %%
import random
x = random.randint(1,100)
i=0

while True:
    n = int(input('guess the num : '))
    i+=1
    if n==x:
        print('Congratulations ! you guessed it',i,'th time')
        break
    elif n<x:
        print('guess higher')
    else:
        print('guess lower')
# Out:
# guess the num :  99
# guess lower
# guess the num :  70
# guess lower
# guess the num :  50
# guess higher
# guess the num :  60
# guess higher
# guess the num :  66
# guess lower
# guess the num :  62
# guess higher
# guess the num :  64
# Congratulations ! you guessed it 7 th time
