# %% [markdown]
# ## Modules :
# ### A file containing set of functions that we can use in our application if needed.
# ### Example of python modules :
# 1. Math
# 2. Random
# 3. os
# 4. time

# %%
# math : 

import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.sqrt(9)
# Out:
# 3.0

# %%
# random : 
import random

# %%
random.randint(1,1000)
# Out:
# 513

# %%
A = [1,2,3,4,5]
random.shuffle(A)
print(A)
# Out:
# [5, 2, 4, 3, 1]

# %%
# time : 

import time

# %%
time.time()
# Out:
# 1739676742.3313766

# %%
time.ctime()
# Out:
# 'Sun Feb 16 03:32:29 2025'

# %%
print('Hello')
time.sleep(1)
print('World')
# Out:
# Hello
# World

# %%
# os : 

import os

# %%
os.getcwd() # will return current working directory
# Out:
# '/kaggle/working'

# %%
os.listdir() # list of all files in the current directory
# Out:
# ['.virtual_documents']
