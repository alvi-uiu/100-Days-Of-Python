# %% [markdown]
# ## Literal is a raw data given to a vairable . In Python there are various type of literals:
# 1. Numeric
# 2. String
# 3. Boolean
# 4. Special

# %%
# 1. Numeric Literals : 

a = 0b1010 # Binary Literals
b = 70 # decimal literal
c = 0o310 # Octal literal
d = 0x12c # hexadecimal literal

print (a,b,c,d)


# Float Literals : 

e = 77.99
f = 77.88e30
g = 77.66e-7

print(e,f,g)

# complex literals : 

x = 7+5j 
print(x ,  x.imag , x.real)
# Out:
# 10 70 200 300
# 77.99 7.788e+31 7.766e-06
# (7+5j) 5.0 7.0

# %%
# 2. String Literals : 

s= 'Hello'
s1= "Bangladesh"
s2="A"
multiLine ="""Its a multiline String"""
unicode = u"\U0001F606"
raw_str = r"C:\Users\name"  # Output: C:\Users\name (backslashes preserved)

print(s)
print(s1)
print(s2)
print(multiLine)
print(unicode)
print(raw_str)
# Out:
# Hello
# Bangladesh
# A
# Its a multiline String
# 😆
# C:\Users\name

# %%
# 3. Boolean Literals : 

print(True + 1)
print(False + 1)
# Out:
# 2
# 1

# %%
# Special Literal : 

# if we need to declare a variable at first , we can decare it by using "None"

a = None
