# %%
# Making a simple log in page : 

correct_email = 'uiu@gmail.com'
correct_pass = 1234

mail = str(input('enter mail : '))
password = int(input('enter pass : '))

if '@' in mail : 
    if mail == correct_email and password == correct_pass:
        print('Welcome')
    elif mail == correct_email and password !=correct_pass:
        print('Give correct pass')
        password = int(input('enter pass again : '))
        if password == correct_pass:
            print('Welcome')
        else:
            print(' wrong again !')
    else:
        print('try again')
else:
    print('incorrect mail')
# Out:
# enter mail :  uiu@gmail.com
# enter pass :  343
# Give correct pass
# enter pass again :  343
#  wrong again !
