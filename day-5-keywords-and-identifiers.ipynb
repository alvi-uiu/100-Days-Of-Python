# %%
# python has 33 keywords : 

import keyword

print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Identifiers : A python identifier is used to identify a variable, function , class , module or other obj

# Rules of setting identifiers : 

# 1. can only start with alphabet or _
# 2. followed by 0 or more letter , _ , digits
# 3. keywords can not be identifiers 


name = 'Alvi'
_ = 'Alvi'
name1='Alvi'
first_name='Alvi'
__='Alvi'

print(name)
print(_)
print(name1)
print(first_name)
print(__)
# Out:
# Alvi
# Alvi
# Alvi
# Alvi
# Alvi
