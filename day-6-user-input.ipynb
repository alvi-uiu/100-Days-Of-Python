# %%
name = input('enter name : ')
print(name)
# Out:
# enter name :  Alvi
# Alvi

# %%
num1=input('enter first num : ')
num2=input('enter second num : ')

print(num1)
print(num2)
# Out:
# enter first num :  77
# enter second num :  99
# 77
# 99

# %%
# user inputs are stored on String format 
# because String is an universal fomat(any data type can be stored inside string)

n = input('enter a num : ')

# by the help of type we can see the type of the variable 

type(n)
# Out:
# enter a num :  99
# str
